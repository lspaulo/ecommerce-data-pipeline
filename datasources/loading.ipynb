# %%
import pandas as pd

df = pd.read_csv("../input-data/Engenharia-Dados/worldcup/WorldCups.csv", index_col=0)

df
# Out:
#            Country      Winner      Runners-Up        Third          Fourth  \
# Year
# 1930       Uruguay     Uruguay       Argentina          USA      Yugoslavia
# 1934         Italy       Italy  Czechoslovakia      Germany         Austria
# 1938        France       Italy         Hungary       Brazil          Sweden
# 1950        Brazil     Uruguay          Brazil       Sweden           Spain
# 1954   Switzerland  Germany FR         Hungary      Austria         Uruguay
# 1958        Sweden      Brazil          Sweden       France      Germany FR
# 1962         Chile      Brazil  Czechoslovakia        Chile      Yugoslavia
# 1966       England     England      Germany FR     Portugal    Soviet Union
# 1970        Mexico      Brazil           Italy   Germany FR         Uruguay
# 1974       Germany  Germany FR     Netherlands       Poland          Brazil
# 1978     Argentina   Argentina     Netherlands       Brazil           Italy
# ...

# %%
import boto3
from io import BytesIO

# %%
# !pip install pyarrow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 3.4 MB/s eta 0:00:00m eta 0:00:010:00:010m
# ...

# %%
# !pip install s3fs
# Out:
# ...
#   Using cached attrs-25.1.0-py3-none-any.whl.metadata (10 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 417.3 kB/s eta 0:00:0031m1.8 MB/s eta 0:00:01
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 854.3 kB/s eta 0:00:00 eta 0:00:010:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.1/78.1 kB 478.0 kB/s eta 0:00:001m1.3 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
# Using cached attrs-25.1.0-py3-none-any.whl (63 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 3.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.6/283.6 kB 1.6 MB/s eta 0:00:004.3 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 972.5 kB/s eta 0:00:0031m7.6 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 1.4 MB/s eta 0:00:004.5 MB/s eta 0:00:01
# ...

# %%
buffer = BytesIO()
df.to_parquet(buffer, engine="pyarrow")

df
# Out:
#            Country      Winner      Runners-Up        Third          Fourth  \
# Year
# 1930       Uruguay     Uruguay       Argentina          USA      Yugoslavia
# 1934         Italy       Italy  Czechoslovakia      Germany         Austria
# 1938        France       Italy         Hungary       Brazil          Sweden
# 1950        Brazil     Uruguay          Brazil       Sweden           Spain
# 1954   Switzerland  Germany FR         Hungary      Austria         Uruguay
# 1958        Sweden      Brazil          Sweden       France      Germany FR
# 1962         Chile      Brazil  Czechoslovakia        Chile      Yugoslavia
# 1966       England     England      Germany FR     Portugal    Soviet Union
# 1970        Mexico      Brazil           Italy   Germany FR         Uruguay
# 1974       Germany  Germany FR     Netherlands       Poland          Brazil
# 1978     Argentina   Argentina     Netherlands       Brazil           Italy
# ...

# %%
s3_client = boto3.client('s3')

bucket_name = "bucket-testing-dnc-btfg"
file_key = "loading/full_data.parquet"

# %%
s3_client.upload_fileobj(buffer, bucket_name, file_key)

# %%
list(df.columns)
# Out:
# ['Country',
#  'Winner',
#  'Runners-Up',
#  'Third',
#  'Fourth',
#  'GoalsScored',
#  'QualifiedTeams',
#  'MatchesPlayed',
#  'Attendance']

# %%
df.index
# Out:
# Index([1930, 1934, 1938, 1950, 1954, 1958, 1962, 1966, 1970, 1974, 1978, 1982,
#        1986, 1990, 1994, 1998, 2002, 2006, 2010, 2014],
#       dtype='int64', name='Year')

# %%
df = df.reset_index()
df
# Out:
#     index  Year       Country      Winner      Runners-Up        Third  \
# 0       0  1930       Uruguay     Uruguay       Argentina          USA
# 1       1  1934         Italy       Italy  Czechoslovakia      Germany
# 2       2  1938        France       Italy         Hungary       Brazil
# 3       3  1950        Brazil     Uruguay          Brazil       Sweden
# 4       4  1954   Switzerland  Germany FR         Hungary      Austria
# 5       5  1958        Sweden      Brazil          Sweden       France
# 6       6  1962         Chile      Brazil  Czechoslovakia        Chile
# 7       7  1966       England     England      Germany FR     Portugal
# 8       8  1970        Mexico      Brazil           Italy   Germany FR
# 9       9  1974       Germany  Germany FR     Netherlands       Poland
# 10     10  1978     Argentina   Argentina     Netherlands       Brazil
# 11     11  1982         Spain       Italy      Germany FR       Poland
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           20 non-null     int64
#  1   Year            20 non-null     int64
#  2   Country         20 non-null     object
#  3   Winner          20 non-null     object
#  4   Runners-Up      20 non-null     object
#  5   Third           20 non-null     object
#  6   Fourth          20 non-null     object
#  7   GoalsScored     20 non-null     int64
#  8   QualifiedTeams  20 non-null     int64
#  9   MatchesPlayed   20 non-null     int64
#  10  Attendance      20 non-null     object
# dtypes: int64(5), object(6)
# memory usage: 1.8+ KB

# %%
df["Year"] = df["Year"].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           20 non-null     int64
#  1   Year            20 non-null     object
#  2   Country         20 non-null     object
#  3   Winner          20 non-null     object
#  4   Runners-Up      20 non-null     object
#  5   Third           20 non-null     object
#  6   Fourth          20 non-null     object
#  7   GoalsScored     20 non-null     int64
#  8   QualifiedTeams  20 non-null     int64
#  9   MatchesPlayed   20 non-null     int64
#  10  Attendance      20 non-null     object
# dtypes: int64(4), object(7)
# memory usage: 1.8+ KB

# %%
import pyarrow
import pyarrow.parquet as pq
import s3fs

# %%
# Salvando no bucket os dados em parquet particionado
pq.write_to_dataset(
    pyarrow.Table.from_pandas(df),
    'bucket-testing-dnc-btfg/loading',
    filesystem=s3fs.S3FileSystem(),
    partition_cols=["Year"]
)
